# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/dssg-pt/covid19pt-data/master/data.csv'
df = pd.read_csv(url, index_col=1)
print(df[["data", "confirmados_novos"]].tail(5))
df[["data", "confirmados_novos"]].plot(figsize=(15,10))
# Out:
#                         data  confirmados_novos
# data_dados
# 23-02-2021 00:00  23-02-2021               1032
# 24-02-2021 00:00  24-02-2021               1480
# 25-02-2021 00:00  25-02-2021               1160
# 26-02-2021 00:00  26-02-2021               1027
# 27-02-2021 00:00  27-02-2021               1071
# <AxesSubplot:xlabel='data_dados'>

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement git
# ERROR: No matching distribution found for git
# Note: you may need to restart the kernel to use updated packages.
